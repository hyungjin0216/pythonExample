# %%
import re
txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)

# %%
import re
txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
# Out:
# ['ai', 'ai']

# %%
import re
txt = "The rain in Spain"
x = re.search("\s", txt)
print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hyung\AppData\Local\Temp\ipykernel_18016\4009967224.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.search("\s", txt)

# %%
import re
txt = "The rain in Spain"
x = re.sub("\s", "9", txt, 2)
print(x)
# Out:
# The9rain9in Spain
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hyung\AppData\Local\Temp\ipykernel_18016\3838997704.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.sub("\s", "9", txt, 2)
# C:\Users\hyung\AppData\Local\Temp\ipykernel_18016\3838997704.py:3: DeprecationWarning: 'count' is passed as positional argument
#   x = re.sub("\s", "9", txt, 2)

# %%
import re
txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.group())
# Out:
# Spain

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
fruit = "apples"
txt = f"I love {fruit.upper()}"
print(txt)
# Out:
# I love APPLES

# %%
def myconverter(x):
    return x * 0.3048
txt = f"The plane is flying at a {myconverter(30000)} meter altitude"
print(txt)
# Out:
# The plane is flying at a 9144.0 meter altitude

# %%
quantity = 3
itemno = 567
price = 49
myorder = "I want {} pieces of item number {} for {:.2f} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 3 pieces of item number 567 for 49.00 dollars.

# %%
print("Enter your name:")
name = input()
print(f"Hello {name}")
# Out:
# Enter your name:
# Hello enter

# %%
name = input("Enter your name:")
print(f"Hello {name}")
fav1 = input("What is your favorite animal:")
fav2 = input("What is your favorite color:")
fav3 = input("What is your favorite number:")
print(f"Do you want a {fav2} {fav1} with {fav3} legs?")
# Out:
# Hello enter
# Do you want a enter enter with enter legs?
