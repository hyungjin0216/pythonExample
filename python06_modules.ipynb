# %%
r = range(10)
print(r[2])
print(r[:3])
# Out:
# 2
# range(0, 3)

# %%
r = range(0, 10, 2)
print(6 in r)
print(7 in r)
# Out:
# True
# False

# %%
def greeting(name):
    print("Hello, " + name)
greeting("hyungjin")
# Out:
# Hello, hyungjin

# %%
person1 = {
    "name": "John",
    "age": 36,
    "country": "Norway"
}

# %%
import platform
x = platform.system()
print(x)
# Out:
# Windows

# %%
def greeting(name):
    print("Hello, " + name)
person1 = {
    "name": "John",
    "age": 36,
    "country": "Norway"
}
greeting(person1["name"])
# Out:
# Hello, John

# %%
import datetime
x = datetime.datetime.now()
print(x.year)
print(x.strftime("%A"))
# Out:
# 2026
# Saturday

# %%
x = pow(4, 3)
print(x)
# Out:
# 64
